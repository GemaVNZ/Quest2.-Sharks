# %%
import plotly.express as px
import pandas as pd


# Import data from USGS
data = pd.read_csv('https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/all_month.csv')


# Drop rows with missing or invalid values in the 'mag' column
data = data.dropna(subset=['mag'])
data = data[data.mag >= 0]


# Create scatter map
fig = px.scatter_geo(data, lat='latitude', lon='longitude', color='mag',
                     hover_name='place', #size='mag',
                     title='Earthquakes Around the World')
fig.show()

# %%
data.head()
# Out:
#                        time   latitude   longitude  depth   mag magType   nst  \
# 0  2024-10-12T10:04:25.920Z  35.066334 -119.092667  12.34  1.71      ml  34.0
# 1  2024-10-12T09:40:18.400Z  36.652700 -117.058400   2.20  0.70      ml  17.0
# 2  2024-10-12T09:21:25.487Z  57.173700 -155.290000   0.30  2.40      ml   NaN
# 3  2024-10-12T09:18:47.830Z  35.083667 -119.078167  13.02  2.25      ml  54.0
# 4  2024-10-12T09:15:47.730Z  40.300667 -124.447830  13.11  2.08      md  10.0
#
#       gap     dmin     rms  ...                   updated  \
# 0   42.00  0.01060  0.2100  ...  2024-10-12T10:06:56.619Z
# 1  255.92  0.30900  0.3039  ...  2024-10-12T09:42:30.138Z
# 2     NaN      NaN  0.7000  ...  2024-10-12T09:23:06.297Z
# 3   40.00  0.02543  0.2400  ...  2024-10-12T09:25:32.375Z
# 4  299.00  0.08142  0.0200  ...  2024-10-12T09:59:27.407Z
#
#                                    place        type horizontalError  \
# 0              20 km NW of Grapevine, CA  earthquake            0.29
# 1  29 km NW of Furnace Creek, California  earthquake             NaN
# 2             66 km SW of Karluk, Alaska  earthquake             NaN
# 3              21 km NW of Grapevine, CA  earthquake            0.22
# 4                14 km W of Petrolia, CA  earthquake            2.96
#
#   depthError  magError  magNst     status  locationSource magSource
# 0       0.73     0.292    24.0  automatic              ci        ci
# 1       8.90     0.320    11.0  automatic              nn        nn
# 2      13.20       NaN     NaN  automatic              ak        ak
# 3       0.55     0.191    27.0  automatic              ci        ci
# 4       1.23     0.120    10.0  automatic              nc        nc
#
# [5 rows x 22 columns]
